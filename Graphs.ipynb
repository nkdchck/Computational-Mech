# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math as mth

# %%
T1 = pd.read_csv('syz_1.csv')
TP = pd.read_csv('syz_2.csv')
T = pd.read_csv('default .csv')

PB = pd.read_csv('p_b.csv')

# %%
T1.head()
# Out:
#       S        SZ
# 0  0.00 -0.022659
# 1  0.07 -0.025473
# 2  0.14 -0.030837
# 3  0.21 -0.037747
# 4  0.28 -0.042444

# %%
plt.title('График изменения напряженийя $\sigma_z$ вдоль прямой y = z = 0 в первой вспомагательной задаче')
plt.plot(T1.S, T1.SZ, '-')
plt.xlabel("y = z = 0")
plt.ylabel(r"$\sigma_z$")
plt.grid()

# %%
TP.head()
# Out:
#       S         SZ
# 0  0.00  3487800.0
# 1  0.07  3810900.0
# 2  0.14  4145800.0
# 3  0.21  4399300.0
# 4  0.28  4109800.0

# %%
plt.title('График изменения напряженийя $\sigma_z$ вдоль прямой y = z = 0 в второй вспомагательной задаче\n')
plt.plot(TP.S, TP.SZ, '-')
plt.xlabel("y = z = 0")
plt.ylabel(r"$\sigma_z$")
plt.grid()

# %%
plt.title('График изменения напряженийя $\sigma_z$ вдоль прямой y = z = 0 в исходной вспомагательной задаче\n')
plt.plot(T1.S, T1.SZ, '-')
plt.plot(TP.S, TP.SZ + T1.SZ, 'o')
plt.plot(T.S, T.SZ, '*')
plt.xlabel("y = z = 0")
plt.ylabel(r"$\sigma_z$")
plt.grid()

# %%
TP.SZ = TP.SZ.multiply(-1)

# %%
PB.SZ = TP.SZ / T1.SZ

# %%
PB.SZ
# Out:
# 0     1.539256e+08
# 1     1.496055e+08
# 2     1.344424e+08
# 3     1.165470e+08
# 4     9.682876e+07
# 5     8.103986e+07
# 6     6.670192e+07
# 7     5.349896e+07
# 8     4.341440e+07
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15    3.006242e+06
# 16   -1.006777e+06
# 17   -5.256328e+06
# 18   -9.798413e+06
# 19   -1.242713e+07
# 20   -1.660758e+07
# Name: SZ, dtype: float64

# %%
plt.title('График изменения напряженийя $\sigma_z$ вдоль прямой y = z = 0 в первой вспомагательной задаче\n')
plt.plot(PB.S, -PB.SZ, '-')
plt.xlabel("y = z = 0")
plt.ylabel(r"$\sigma_z$")
plt.grid()

# %%
T1 = pd.read_csv('syz_1.csv')
TP = pd.read_csv('syz_2.csv')
T = pd.read_csv('default .csv')

# %%
T.SZ = -TP.SZ + (PB.SZ * T1.SZ)

# %%
plt.title('График изменения напряженийя $\sigma_z$ вдоль прямой y = z = 0 в исходной задаче\n')
plt.plot(T.S, T.SZ, '-')

plt.xlabel("y = z = 0")
plt.ylabel(r"$\sigma_z$")
plt.grid()
